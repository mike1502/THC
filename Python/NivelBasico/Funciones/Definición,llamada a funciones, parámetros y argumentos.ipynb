# %% [markdown]
# <a href="https://colab.research.google.com/github/mike1502/THC/blob/main/Python/NivelBasico/Funciones/Definici%C3%B3n%2Cllamada%20a%20funciones%2C%20par%C3%A1metros%20y%20argumentos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <font color="Red" face="Comic Sans MS,arial">
#   <h1 align="center"><i>Definición,llamada a funciones, parámetros y argumentos </i></h1>
#   </font>
#
# > Elaborado por: Jesús Iván Coss Calderón. mat_ing_coss@ciencias.unam.mx
#
# > Modificado por: Miguel Ángel Carrillo Lucía. miguelcarrillo15@ciencias.unam.mx

# %% [markdown]
# **Objetivo general**
#
# * Aprender los fundamentos de la declaración de funciones
#
# **Objetivos particulares**
#
# * Entender la elaboración de funciones

# %% [markdown]
# [**Regresa al notebook principal**](https://github.com/seismomat/HerramientasComputacionales/blob/main/Sintaxis%2Ccomentarios%2CTiposDeDatos.ipynb)

# %% [markdown]
# <a name='c1'></a>
#
# ## Contenido
# - [Variables globales](#1)
#     - [La clave global](#1-1)
# - [Funciones](#2)
#     - [Declaración](#2-1)
#     - [Llamando funciones creadas](#2-2)
# - [Argumentos](#3)
#     - [¿Argumentos o parámetros?](#3-1)
# - [Número de argumentos](#4)
#     - [*args](#4-1)
#     - [Clave Arguments](#4-2)
#     - [**kwargs](#4-3)
# - [Parámetro default](#5)
# - [Pasando una estructura de datos como parámetros](#6)
# - [Un ejemplo numérico](#7)
# - [Repasando el concepto de variable local y global](#8)

# %% [markdown]
# <a name='6'></a>
#
# # Variables globales
# [regresar al contenido](#c1)
#
# Las variables que se crean fuera de una función (como en todos los ejemplos anteriores) se conocen como variables globales.
#
# Las variables globales pueden ser utilizadas por todos, tanto dentro de funciones como fuera de ellas.

# %%
x = "awesome"

def myfunc():
  print("Python is " + x)

myfunc()
# Out:
# Python is awesome

# %% [markdown]
# Si creas una variable con el mismo nombre dentro de una función, esta variable será **local** y solo se podrá usar dentro de la función. La variable global con el mismo nombre permanecerá como estaba, global y con el valor original.

# %%
x = "awesome"

def myfunc():
  x = "fantastic"
  print("Python is " + x)

myfunc()

print("Python is " + x)
# Out:
# Python is fantastic
# Python is awesome

# %% [markdown]
# <a name='6-1'></a>
#
# ## La clave Global
# [regresar al contenido](#c1)
#
# Normalmente, cuando creas una variable dentro de una función, esa variable es local y solo se puede usar dentro de esa función.
#
# Para crear una variable global dentro de una función, puedes usar la palabra clave global.

# %%
x = "awesome"
def myfunc():
    global x
    x = "fantastic"
    print("Python is " + x)

myfunc()

print("Python is " + x)
# Out:
# Python is fantastic
# Python is fantastic

# %% [markdown]
# Si usas la palabra clave global, la variable pertenece al ámbito global.

# %% [markdown]
# <a name='2'></a>
#
# # Funciones
# [regresar al contenido](#c1)
#
# Una función es un bloque de código que solo se ejecuta cuando se llama.
#
# Puedes pasar datos, conocidos como parámetros, a una función.
#
# Una función puede devolver datos como resultado.

# %% [markdown]
# <a name='2-1'></a>
#
# ## Declaración
# [regresar al contenido](#c1)
#
# En Python, una función se define usando la palabra clave **def** seguido de dos puntos **:**

# %%
def mi_funcion():
  print("Hola estimados estudiantes. Estamos viendo el tema de funciones en Python.")

# %% [markdown]
# <a name='2-2'></a>
#
# ## Llamando funciones creadas
# [regresar al contenido](#c1)
#
# Para llamar a una función, utiliza el nombre de la función seguido de paréntesis.

# %%
mi_funcion()
# Out:
# Hola estimados estudiantes. Estamos viendo el tema de funciones.

# %% [markdown]
# <a name='3'></a>
#
# # Argumentos
# [regresar al contenido](#c1)
#
# La información puede ser pasada a las funciones como argumentos.
#
# Los argumentos se especifican después del nombre de la función, dentro de los paréntesis. Puedes agregar tantos argumentos como desees, simplemente sepáralos con comas.
#
# El siguiente ejemplo tiene una función con un argumento (fname). Cuando la función es llamada, pasamos un nombre propio, que es usado dentro de la función para imprimir el nombre completo.

# %%
def mi_funcion_nueva(fname):
    print("Hola "+fname +". Esta es la clase de Funciones en Python.")

mi_funcion_nueva("Miguel y Leonardo")
# Out:
# Hola Miguel y Leonardo. Esta es la clase de Funciones.

# %% [markdown]
# <a name='3-1'></a>
#
# ## ¿Argumentos o parámetros?
# [regresar al contenido](#c1)
#
# Los términos "parámetro" y "argumento" pueden ser usados para referirse a lo mismo: información que es pasada a una función.

# %% [markdown]
# Desde la perspectiva de una función:
#
# Un parámetro es la variable que se enumera dentro de los paréntesis en la definición de la función.
#
# Un argumento es el valor que se envía a la función cuando se llama a la misma.

# %% [markdown]
# <a name='4'></a>
#
# # Número de argumentos
# [regresar al contenido](#c1)

# %% [markdown]
# Por defecto, una función debe ser llamada con el número correcto de argumentos. Esto significa que si tu función espera 2 argumentos, debes llamar a la función con 2 argumentos, ni más ni menos.

# %%
def Nombre(fname,lname):
    print("Hola "+fname + " " + lname+ ". Esta es la clase de Funciones en Python.")

Nombre("Miguel y","Leonardo")
# Out:
# Hola Miguel y Leonardo. Esta es la clase de Funciones en Python.

# %% [markdown]
# <a name='4-1'></a>
#
# ## *args
# [regresar al contenido](#c1)
#
# Si no sabes cuántos argumentos se pasarán a tu función, agrega un * antes del nombre del parámetro en la definición de la función.
#
# De esta manera, la función recibirá una **tupla** de argumentos y podrá acceder a los elementos correspondientes.

# %%
def mi_funcion(*kids):
    print("El niño menor es " + kids[2])

mi_funcion("Emil", "Tobias", "Linus")
# Out:
# El niño menor es Linus

# %% [markdown]
# <a name='4-2'></a>
#
# ## Clave Arguments
# [regresar al contenido](#c1)
#
# También puedes enviar argumentos utilizando la sintaxis clave = valor.
#
# De esta manera, el orden de los argumentos no importa.

# %%
def mi_funcion(niño3,niño2,niño1):
    print("El niño menor es " + niño3)

mi_funcion(niño1 = "Emil", niño2 = "Tobias", niño3 = "Linus")
# Out:
# El niño menor es Linus

# %% [markdown]
# <a name='4-3'></a>
#
# ## **kwargs
# [regresar al contenido](#c1)
#
# Si no sabes cuántos argumentos de palabras clave se pasarán a tu función, agrega dos asteriscos: ** antes del nombre del parámetro en la definición de la función.
#
# De esta manera, la función recibirá un diccionario de argumentos y podrá acceder a los elementos correspondientes.

# %%
def mi_funcion(**kid):
  print("El apellido es " + kid["Ape"])

mi_funcion(nombre = "Juan", Ape = "Pérez")
# Out:
# El apellido es Pérez

# %% [markdown]
# <a name='5'></a>
#
# # Parámetro default
# [regresar al contenido](#c1)
#
# El siguiente ejemplo muestra cómo usar un valor de parámetro predeterminado.
#
# Si llamamos a la función sin argumento, utiliza el valor predeterminado.

# %%
def mi_funcion(pais="México"):
    print("Yo soy de "+ pais)

mi_funcion()
# Out:
# Yo soy de México

# %%
mi_funcion("Alemania")
# Out:
# Yo soy de Alemania

# %% [markdown]
# <a name='6'></a>
#
# # Pasando una estructura de datos como parámetros
# [regresar al contenido](#c1)
#
# Puedes enviar cualquier tipo de dato como argumento a una función (cadena, número, lista, diccionario, etc.), y se tratará como el mismo tipo de dato dentro de la función.
#
# Por ejemplo, si envías una lista como argumento, seguirá siendo una lista cuando llegue a la función.

# %%
def mi_funcion(frutas):
  for x in frutas:
    print(x)

frutas = ["manzana", "banana", "mora"]

mi_funcion(frutas)
# Out:
# manzana
# banana
# mora

# %% [markdown]
# <a name='7'></a>
# # Un ejemplo numérico

# %% [markdown]
# El comando **return** sirve para devolver un resultado desde una función al lugar donde fue llamada.

# %%
#Calcular el área de un triángulo
def area_triangulo(base, altura):
    return (base * altura) / 2

# Imprime el resultado en pantalla e ingresa los valores como argumentos (base y altura).
print("Área del triángulo:", area_triangulo(10, 5))

# %%
##O bien se puede hacer de esta forma, solicitando los datos al usuario.
base = float(input("Ingresa la base del triángulo: "))
altura = float(input("Ingresa la altura del triángulo: "))

# Llamar a la función
area = area_triangulo(base, altura)

print("El área del triángulo es:", area)

# %% [markdown]
# <a name='8'></a>
# #Repasando el concepto de variable local y global.

# %%
def sumar(a, b):
    s=a+b
    print(s)
#print("la suma es",s)
#resultado = sumar(5, 3)
#print(s)
#sumar(5,3)
#print("la suma es",sumar(5,3))

# %%
#Veamos la resta
resultado = 0

def restar(a, b):
    diferencia = a - b
    return diferencia


resultado = restar(10, 4)

#print(diferencia)
#print(resultado)
#print(Resultado)
#print(return)
#print("La resta es:", resultado)
