# %% [markdown]
# <a href="https://colab.research.google.com/github/mike1502/THC/blob/main/Ejercicio30Sept2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#ejemplos con división entera
manzanas=50
personas=6
repartir=manzanas//personas
print(repartir)

faltan=manzanas%personas
print("sobran",faltan)
# Out:
# 8
# sobran 2

# %%
dias=100
dias_por_semana=7
semanas_totales=dias//dias_por_semana
print(semanas_totales)

semanas_que_sobran=dias%dias_por_semana
print("sobran",semanas_que_sobran)
# Out:
# 14
# sobran 2

# %%
a=int(input("ingrese el valor de a:"))
b=int(input("ingrese el valor de b:"))
c=int(input("ingrese el valor de c:"))

s=(a+b+c)/2

a1=s-a
a2=s-b
a3=s-c
print(s)
Area=(s*a1*a2*a3)**(1/2)
print("el area del triángulo es:",Area)
# Out:
# ingrese el valor de a:7
# ingrese el valor de b:8
# ingrese el valor de c:9
# 12.0
# el area del triangulo es: 26.832815729997478
