# %%
#Programa de divisas
print("Conversión de divisas (dólares americanos):")
print("\nTasas de cambio")
print("1 USB= 18.38 MXN (Pesos mexicanos)") ## ¿QUÉ ES USB? La abreviación del dolar generalmente la encuentras como USD
print("1 USB= 0.85 EUR (Euros)")
print("1 USB= 0.74 GBP (Libras esterlinas)")
print("1 USB= 7.12 CNY (Yuan chino)")
print("1 USB= 81.56 RUB (Rublos rusos)")
cantidad= float(input("\nCantidad deseada a convertir (USD):"))  #En lugar de cantidad, que sea dolar, dolares. dol...
# por que puede ser cantidad, pero no sé bien si es moneda, temperatura, etc. Asócialo con el problema que estás resolviendo.
pesos=18.38*cantidad
euros=0.85*cantidad
libras=0.74*cantidad
yuan=7.12*cantidad
rublos=81.56*cantidad
p=round(pesos, 1)
e=round(euros, 1)
g=round(libras, 1) # ¿qué me dice la variable g? ¿con cuál moneda la asocio?
c=round(yuan, 1) #lo mismo con la letra c
r=round(rublos,1) #usa nombres más descriptivos
#Round no funciona como lo tienes, a 2 decimales, porque a veces solo te queda un decimal. Te puedes ahorrar ese paso.
#Si quieres redondear (o definir cuantos) decimales quieres mostrar,
#te sugiero mejor usar el formato f-string con concatenación para print, tal como te lo muestro abajo.

print("verificar decimales",e) # aquí hago una prueba para ver los decimales
print("\nConversiones:")
print(p,"MXN")
print(e,"EUR")
print(g,"GBP")
print(c,"CNY")
print(r,"RUB")
#Puedes imprimir los resultados de esta forma:
print(f"{cantidad:.3f} (USD) son/equivale a {p:.3f} pesos mexicanos (MXN)") #puedes poner 2 o 3 decimales.
#Este último print lo puedes repetir para las otras monedas.
#O bien:
print(f"{cantidad:.3f} (USD) son/equivale a {round(p,2)} pesos mexicanos (MXN)") # Se puede simplificar más tu código.
#El problema cumple el objetivo. Obtener divisas. Bien hecho.
# Out:
# Conversión de divisas (dólares americanos):
#
# Tasas de cambio
# 1 USB= 18.38 MXN (Pesos mexicanos)
# 1 USB= 0.85 EUR (Euros)
# 1 USB= 0.74 GBP (Libras esterlinas)
# 1 USB= 7.12 CNY (Yuan chino)
# 1 USB= 81.56 RUB (Rublos rusos)
#
# Cantidad deseada a convertir (USD):2354
# verificar decimales 2000.9
#
# Conversiones:
# 43266.5 MXN
# 2000.9 EUR
# 1742.0 GBP
# 16760.5 CNY
# 191992.2 RUB
# 2354.000 (USD) son/equivale a 43266.500 pesos mexicanos (MXN)
# 2354.000 (USD) son/equivale a 43266.5 pesos mexicanos (MXN)

# %%
#Programa de números y operaciones
p_n= float(input("Ingrese el primer número:"))
s_n= float(input("Ingrese el segundo número:"))
suma=p_n+s_n
resta=p_n-s_n
multi=p_n*s_n
div=p_n/s_n
pot_1=p_n**2
pot_2=s_n**2
raiz1=p_n**0.5
raiz2=s_n**0.5
#Aquí lo mismo, mejor imprime con f-string. Es mejor redondear al imprimir.
#La declaración de variables puede ser más sencilla.
p=round(pot_1, 2)
s=round(suma, 2)
r=round(resta, 2)
m=round(multi, 2)
d=round(div, 2)
p1=round(pot_1, 2)
p2=round(pot_2, 2)
r1=round(raiz1, 2)
r2=round(raiz2, 2)
print("\nOperaciones:")
print("Suma:",s)
print("Resta:",r)
print("Multiplicación:",m)
print("División:",d)
print("Potencias:",p1,",",p2)
print("Raíces cuadradas:",r1,",",r2)
# Out:
# Ingrese el primer número:212.2134
# Ingrese el segundo número:32456.425
#
# Operaciones:
# Suma: 32668.64
# Resta: -32244.21
# Multiplicación: 6887688.3
# División: 0.01
# Potencias: 45034.53 , 1053419523.78
# Raíces cuadradas: 14.57 , 180.16

# %%
#Programa descuentos
print("Calculadora de descuentos")
precio_0=float(input("Ingrese el precio del producto:")) #Puede ser precio_inicial
descuento=float(input("Ingrese el porcentaje de descuento:"))
s=descuento*precio_0/100  #se ve un poco raro esta operación con el cero y la división ahí juntos. Estaría bien poner un paréntesis a precio_0
precio_f=precio_0-s #
w=round(precio_f,2) #puede ir dentro del print en la siguiente línea.
print("El precio final es:",w)
# Out:
# Calculadora de descuentos
# Ingrese el precio del producto:980
# Ingrese el porcentaje de descuento:50
# El precio final es: 490.0

# %%
#Programa de conversión de coordenadas y localización geográfica
_1_la_d=40
_1_la_m=41
_1_la_s=21
_1_lo_d=74
_1_lo_m=2
_1_lo_s=40

_2_la_d=48
_2_la_m=51
_2_la_s=12
_2_lo_d=2
_2_lo_m=20
_2_lo_s=55

_3_la_d=34
_3_la_m=3
_3_la_s=8
_3_lo_d=151
_3_lo_m=12
_3_lo_s=33

c1=_1_la_d+_1_la_m/60+_1_la_s/3600
c2=_1_lo_d+_1_lo_m/60+_1_lo_s/3600
c3=_2_la_d+_2_la_m/60+_2_la_s/3600
c4=_2_lo_d+_2_lo_m/60+_2_lo_s/3600
c5=_3_la_d+_3_la_m/60+_3_la_s/3600
c6=_3_lo_d+_3_lo_m/60+_3_lo_s/3600

# NO ES MUY LEGIBLE EL CÓDIGO CON ESTA DECLARACIÓN DE VARIABLES AL INICIO.
# PUEDES USAR UNA SINTÁXIS A LA QUE TE MUESTRO A CONTINUACIÓN
#####
"""
lat1_deg = 40
lat1_min = 41
lat1_sec = 21
"""
#####
## En las líneas que siguen, tanto en la declaración de variables como la sentencia round
#se puede simplificar en el print.
_1=round(c1,3)
_2=round(c2,3)
_3=round(c3,3)
_4=round(c4,3)
_5=round(c5,3)
_6=round(c6,3)
print("Lugares emblemáticos:")
print("\n1.-La estatua de la Libertad, Nueva York, USA")
print("Coordenadas","(",_1,",","-",_2,")")
print("\n2.-Catedral de Notre Dame, Paris, Francia")
print("Coordenadas","(",_3,",",_4,")")
print("\n3.-Ópera de Sídney, Australia")
print("Coordenadas","(-",_5,",",_6,")")
## ME PERDÍ UN POCO EN TU DECLARACIÓN DE VARIABLES.
## TUS RESULTADOS SON CORRECTOS. BUEN TRABAJO.
# Out:
# Lugares emblemáticos:
#
# 1.-La estatua de la Libertad, Nueva York, USA
# Coordenadas ( 40.689 , - 74.044 )
#
# 2.-Catedral de Notre Dame, Paris, Francia
# Coordenadas ( 48.853 , 2.349 )
#
# 3.-Ópera de Sídney, Australia
# Coordenadas (- 34.052 , 151.209 )

# %%
#Ejercicio de física
m=2   # VALOR DE LA MASA
h=0.1 # VALOR DE LA ALTURA
ve=(3**2) # velocidad, velocity, vel
v=3
g=9.8 #VALOR DE LA GRAVEDAD
Ec=(m*ve)/2
Ep1=m*g*h  #¿POR QUÉ UNO?
Emt1=Ec+Ep1 #
ep=round(Ep1,2) #PUEDEN IR EN EL PRINT
ec=round(Ec,2)
print("Ejercicio de física")
print("\nDatos:")
print("Masa:",m, "kg")  #OK
print("Altura:",h, "m") #OK
print("Velocidad:",v, "m/s") #OK
print("Gravedad considerada a:",g,"m/s^2") #OK
print("\nResultados:")
print("Energia cinética:",ec,"J")
print("Energia potencial:",ep,"J")
print("Energia total:",Emt1,"J") #BIEN HECHO.
# Out:
# Ejercicio de física
#
# Datos:
# Masa: 2 kg
# Altura: 0.1 m
# Velocidad: 3 m/s
# Gravedad considerada a: 9.8 m/s^2
#
# Resultados:
# Energia cinética: 9.0 J
# Energia potencial: 1.96 J
# Energia total: 10.96 J

# %%
#Programa identificación de enteros
entrada=input("Ingrese su un número entero:")
if float(entrada)%2==1: print("Es un entero impar")
elif float(entrada)%2==0: print("Es un entero par")
else: print("No es un entero")
#BIEN HECHO.
# Out:
# Ingrese su un número entero:7
# Es un entero impar

# %%
#Programa triángulo
"""
Si ingreso cero tanto para a, b y c, me arroja que existe un triángulo.
Está mal el ejercicio. Te faltó esa condición.
Aquí te pongo lo que debes añadir:

if a <= 0 or b <= 0 or c <= 0:
    print("No existe el triángulo (los lados deben ser positivos).")

"""
print("Tipo de triángulo")
a=float(input("Ingrese el valor del primer lado:"))
b=float(input("Ingrese el valor del segundo lado:"))
c=float(input("Ingrese el valor del tercer lado:"))
if a==b==c: print("Es un triángulo equilátero")
elif a==b!=c or a!=b==c or a==c!=b: print("Es un triángulo isósceles")
elif a!=b!=c: print("Es un triángulo escaleno")
else: print("No es un triángulo")
# Out:
# Tipo de triángulo
# Ingrese el valor del primer lado:0
# Ingrese el valor del segundo lado:0
# Ingrese el valor del tercer lado:0
# Es un triángulo equilátero

# %%
#Programa que determina al mayor de 3 números
print("Programa que determina al mayor de 3 números\n")
a=float(input("Ingrese el número a "))
b=float(input("Ingrese el número b "))
c=float(input("Ingrese el número c "))

if a==b==c: print("Son todos iguales")
elif a==b and a>c: print("Los números a y b son mayores")
elif a==c and a<b: print("El número b es el mayor")
elif b==c and b<a: print("El número a es el mayor")
elif a>b and a>c: print("El número a es el mayor")
elif b>a and b>c: print("El número b es el mayor")
else: print("El número c es el mayor")
#BUEN TRABAJO
# Out:
# Programa que determina al mayor de 3 números
#
# Ingrese el número a 0.01
# Ingrese el número b 0.02
# Ingrese el número c -0.01
# El número b es el mayor

# %%
#Programa de rectas
print("Programa de rectas")
m1x=float(input("Ingresa la pendiente de la recta 1:"))
b1=float(input("Ingresa el valor de b de la recta 1:"))
m2x=float(input("Ingresa la pendiente de la recta 2:"))
b2=float(input("Ingresa el valor de b de la recta 2:"))

"""
CUIDADO AQUÍ. SI DESCOMENTO LAS DOS LÍNEAS QUE SIGUEN, EL PROGRAMA
NO FUNCIONA (X1 NO ESTÁ DEFINIDO). VERIFICA QUE TUS PROGRAMAS SE EJECUTEN BIEN ANTES DE ENVIARLOS.
ESTA VEZ TE LA DOY POR BUENA.

#y1=(m1x*x1)+b1
#y2=(m2x*x2)+b2
"""
print("\nRectas\n")
if m1x==m2x and b1==b2: print("Son la misma recta")
elif m1x==m2x and b1!=b2: print("Las rectas son paralelas")
elif m1x==(-1/m2x) or m2x==(-1/m1x): print("Las rectas son perpendiculares")
else: print("Las rectas se intersectan")
# Out:
# Programa de rectas
# Ingresa la pendiente de la recta 1:1
# Ingresa el valor de b de la recta 1:2
# Ingresa la pendiente de la recta 2:2
# Ingresa el valor de b de la recta 2:1
#
# Rectas
#
# Las rectas se intersectan

# %%
"""
LE FALTAN DETALLES A TU PROGRAMA. YO QUERÍA SABER LOS SIGUIENTES AÑOS BISIESTOS PERO ME ARROJA QUE NO NACÍ DESPUÉS DE 2025¿?.
PARA EL AÑO 2025, NO IMPRIME NADA, ¿ES BISIESTO O NO?.
1900 NO ES AÑO BISIESTO Y TE LO MARCA COMO BISIESTO. RECUERDA QUE LOS AÑOS MÚLTIPLOS DE 100 NO SON BISIESTOS... A MENOS QUE SEAN MÚLTIPLOS DE 400.
AQUÍ TE DEJO UN CÓDIGO MÁS SIMPLIFICADO DE LO QUE FALTÓ HACER.

a = int(input("Ingresa el año: "))

if a % 400 == 0:
  print("El año es bisiesto")
elif a % 100 == 0:
  print("El año no es bisiesto")
elif a % 4 == 0:
  print("El año es bisiesto")
else:
  print("Tu año de nacimiento no es bisiesto") #prueba con 2031
"""
año=float(input("Ingresa tu año de nacimiento: ")) #¿POR QUÉ EL AÑO DE NACIMIENTO?
n=año%4
if año<2025: #¿POR QUÉ ANTES DE 2025?
  if n==0: print("Tu año de nacimiento es bisiesto")
  elif n==1 or n==2 or n==3: print("Tu año de nacimiento no es bisiesto") #NO ENTIENDO QUÉ QUERÍAS HACER AQUÍ. SE PUEDE REDUCIR A UN ELSE
elif año>2025: print("Error, no pudiste haber nacido en ese año. Volver a ejecutar")
# Out:
# Ingresa el año: 2031
# Tu año de nacimiento no es bisiesto
